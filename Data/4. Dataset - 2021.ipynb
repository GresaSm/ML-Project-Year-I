# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ## Uniting the datasets

# %%
import pandas as pd
import numpy as np
from google.colab import files

# link for january
link = 'https://drive.google.com/file/d/1vF_CWfJjflYBDPWY4RphGEHR3pjXrwE2/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('january_2019.csv') 
 
january = pd.read_csv('january_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6,214,215,225,273,319) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for february
link = 'https://drive.google.com/file/d/1dA6flhVMmf4m_j1PW6Wq3eexpIjxzoeg/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('february_2019.csv') 
 
february = pd.read_csv('february_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (95,211,307,314,317,318,320,322,326,327,329) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for march
link = 'https://drive.google.com/file/d/1q2EWAtxI3vXjlLFMU1wiABjJbihrg4cW/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('march_2019.csv') 
 
march = pd.read_csv('march_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6,97,175,176,215,216,226,274,320) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for april
link = 'https://drive.google.com/file/d/1rDSe0vwWsjYkiQ4fVjcvcRvxyzVulxbN/view?usp=share_link' # The shareable link

# to get the id part of the file
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('april_2019.csv') 
 
april = pd.read_csv('april_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (18,94,95,107,115,120) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for may
link = 'https://drive.google.com/file/d/16fQxRKL_NtOLwtPIsVo4p0COr-H9T0E9/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('may_2019.csv') 
 
may = pd.read_csv('may_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6,97,215,216,226,274,320) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for june
link = 'https://drive.google.com/file/d/1DzBO0ZOugrPWVqRPObCPdosgEihGZAwY/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('june_2019.csv') 
 
june = pd.read_csv('june_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6,215,216,226,274,320) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for july
link = 'https://drive.google.com/file/d/1brwrvHq7tHiZF3ZTiaCsZ40WP3oQJMPX/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('july_2019.csv') 
 
july = pd.read_csv('july_2019.csv')

# %%
# link for august
link = 'https://drive.google.com/file/d/1vF_CWfJjflYBDPWY4RphGEHR3pjXrwE2/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('august_2019.csv') 
 
august = pd.read_csv('august_2019.csv')

# %%
# link for september
link = 'https://drive.google.com/file/d/1a4NgxEDFd3idQMqU4iaAzfjvq967Fjiz/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('september_2019.csv') 
 
september = pd.read_csv('september_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (19,90,95,108,116) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for october
link = 'https://drive.google.com/file/d/19EtRaBNdk7u9dtPHI-1wz3VE3VNzKL9k/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('october_2019.csv') 
 
october = pd.read_csv('october_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (8,21,23,92,96,98,110,118,124,142,154,199,284) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for november
link = 'https://drive.google.com/file/d/1yMNu34fYBka2KMkudNc9QMNBCm7Xy9We/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('november_2019.csv') 
 
november = pd.read_csv('november_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (19,21,34,45,48,62,79,96,108,116,183,197,294,297,308,312,314) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# link for december
link = 'https://drive.google.com/file/d/1EmFPFOqNW-C7dRLZ6vrgVb9-HaTXCUfd/view?usp=share_link' # The shareable link

# getting the id part of the link
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('december_2019.csv') 
 
december = pd.read_csv('december_2019.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (17,92,94,106,114,179,193) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Uniting the 12 months
df_2021 = [january, february, march, april, may, june, july, august, september, october, november, december]
df_2021 = pd.concat(df_2021).reset_index()

# %% [markdown]
# ## Cleaning the data

# %%
# Keeping only the relevant columns for our study
df_2021 = df_2021[['P388', 'P6440', 'P6790', 'P6870', 'P6880', 'P6915', 'P6990',
       'P7020', 'P7040', 'P1881', 'P7090', 'P7130', 'P7170S1', 'P7170S6',
       'P514', 'P515', 'P7240', 'P6020', 'P6050', 'P6070',
       'P6125', 'P6160', 'P6170', 'P6210', 'P6240', 'P7480S1', 'P7480S3',
       'P7480S4', 'P7480S5', 'P7480S6', 'P7480S7', 'P7480S8', 'P7480S9',
       'P7480S10', 'P7480S11', 'P7505', 'MES', 'DPTO', 'base', 'CLASE']]

# %%
# Seeing the dimensions of our model
df_2021.shape
# Out:
# (440452, 40)

# %% [markdown]
# ## Data Cleaning
#
# ### Getting rid of nas

# %%
# Create a dataframe which reflects the amount of nas for each column
df_2 = df_2021.isna().sum()

# analyzing which ones have NA's
df_2[df_2 != 0]
# Out:
# CLASE    85290
# dtype: int64

# %%
# Dropping the column
df_2021.drop("CLASE", axis = 1)
# Out:
#         P388  P6440  P6790  P6870  P6880  P6915  P6990  P7020  P7040  P1881  \
# 0         13      1     11      4      7      1      1      1      2      5
# 1         13      2     12      1      4      2      2      1      2     11
# 2         13      2     12      1      1      2      2      1      1     14
# 3         13      2     12      2      6      2      2      1      2      3
# 4         13      2     12      2      6      5      2      1      2      3
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 440447    76      1      6      1      2      3      2      1      1      3
# 440448    23      2     12      1      2      2      2      1      2     12
# 440449    23      2     12      1      8      2      2      1      2      3
# 440450    23      1     12      2      8      2      2      1      2     10
# 440451    23      1     12      4      8      2      2      1      2     11
#
# ...

# %% [markdown]
# ### Getting rid of empty values

# %%
# Using the replace function to replace all empty values for the value 1000
df_3 = df_2021.replace(" ", 1000, regex = True)

# Create a dataframe which is a table wich counts the amount of 1000 in each column
df_3 = df_3[(df_3 == 1000)].count().sort_values()

# We find no columns with empty values
df_3[df_3 != 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Understanding our Data Distribution

# %%
# defining a new dataframe for safe keeping
df_4 = df_2021

# Replace all 2 for 0
df_5 = df_4["P6440"].replace(2, 0, regex = True)

# Separating the dependant variable
print((f"{len(df_5[df_5 == 1])} do not have a contract, while {len(df_5[df_5 == 0])} have it"))
# Out:
# 238624 do not have a contract, while 201828 have it

# %%
print((f"{round((len(df_5[df_5 == 1])/len(df_5))*100, 2)}% do not have a contract, while {round((len(df_5[df_5 == 0])/len(df_5))*100, 2)}% have it"))
# Out:
# 54.18% do not have a contract, while 45.82% have it

# %%
# Loading plt
import matplotlib.pyplot as plt

# Generating the variables
a = [round((len(df_5[df_5 == 0])/len(df_5))*100,2),round((len(df_5[df_5 == 1])/len(df_5))*100,2)]
b = ["Contract","No Contract"]

# Plotting our variables
plt.bar(b,a,color=['orange','tomato'],width = 0.5, alpha = 0.7)

# Labelling our Plot
plt.ylabel("Class frequency [in %]")
plt.title("Class Frequency in the Testing Set [2021]");

# %% [markdown]
# ### Prepping the Data

# %%
# Seeing our columns
df_2021.columns.values
# Out:
# array(['P388', 'P6440', 'P6790', 'P6870', 'P6880', 'P6915', 'P6990',
#        'P7020', 'P7040', 'P1881', 'P7090', 'P7130', 'P7170S1', 'P7170S6',
#        'P514', 'P515', 'P7240', 'P6020', 'P6050', 'P6070', 'P6125',
#        'P6160', 'P6170', 'P6210', 'P6240', 'P7480S1', 'P7480S3',
#        'P7480S4', 'P7480S5', 'P7480S6', 'P7480S7', 'P7480S8', 'P7480S9',
#        'P7480S10', 'P7480S11', 'P7505', 'MES', 'DPTO', 'base', 'CLASE'],
#       dtype=object)

# %%
# settig up the y variable
df_2021['P6440'] = df_2021['P6440'].replace(2,0,regex = True)

# switching the values of base, from strings to numeric categories
df_2021['base'] = df_2021['base'].replace("Area", 1, regex = True)
df_2021['base'] = df_2021['base'].replace("Cabecera", 2, regex = True)
df_2021['base'] = df_2021['base'].replace("Resto", 3, regex = True)

# %%
# Transforming all variables to float
df_2021 = df_2021.astype(float)

# Transforming all variables to string
df_2021 = df_2021.astype(str)

# Change variable type back to folat for our only numeric variable                
df_2021 = df_2021.astype({"P6790": float})

# %%
# Defining dependant variable
y_21 = df_2021['P6440']

# setting the rest of the database
X_21 = df_2021.drop(['P6440'],axis=1)

# %% [markdown]
# ## Loading and prepping the 2019 dataset

# %%
# link for our 2019 dataset 
link = 'https://drive.google.com/file/d/1xPGOMsOXflvfzd0gcYt6pQ1XHEpCyl8l/view?usp=share_link' # The shareable link

# to get the id part of the file
id = link.split("/")[-2]
 
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile('full_dataset_2019.csv') 
 
df_2019 = pd.read_csv('full_dataset_2019.csv')

# %%
# Transforming all variables to float
df_2019 = df_2019.astype(float)

# Transforming all variables to string
df_2019 = df_2019.astype(str)

# Change variable type back to folat for our only numeric variable                
df_2019 = df_2019.astype({"P6790": float})

# %%
# switching the values of base, from strings to numeric categories
df_2019['base'] = df_2019['base'].replace("Area", 1, regex = True)
df_2019['base'] = df_2019['base'].replace("Cabecera", 2, regex = True)
df_2019['base'] = df_2019['base'].replace("Resto", 3, regex = True)

# %%
# Defining dependant variable
y_19 = df_2019['P6440']

# setting the rest of the database
X_19 = df_2019.drop(['P6440'],axis=1)

# %% [markdown]
# ## Training the Model

# %%
categorical = ['P388', 'P6790', 'P6870', 'P6880', 'P6915', 'P6990',
       'P7020', 'P7040', 'P1881', 'P7090', 'P7130', 'P7170S1', 'P7170S6',
       'P514', 'P515', 'P7240', 'P6020', 'P6050', 
       'P6125', 'P6160', 'P6170', 'P6210', 'P6240', 'P7480S1',
       'P7480S3', 'P7480S4', 'P7480S5', 'P7480S6', 'P7480S7', 'P7480S8',
       'P7480S9', 'P7480S10', 'P7480S11', 'P7505', 'MES', 'DPTO', 'base',
       'CLASE']

numerical = ["P6790"]

# %%
# Setting up the training and testing set
X_train_19, X_test_19, y_train_19, y_test_19 = train_test_split(X_19 ,y_19 ,test_size = 0.30, random_state=573)

# %%
# We drop our first dummy to make it easier to interpret
ohe = OneHotEncoder(handle_unknown='ignore')
se = StandardScaler()

# Preprocess 
preprocessor = ColumnTransformer(
    transformers = [
        ("num",StandardScaler(),numerical),
        ("cat",ohe,categorical),
    ]
)

# %%
# Create a pipeline
pipe_tree = Pipeline([
    ('preproc', preprocessor),
    ('model', DecisionTreeClassifier())
    ])

# %% [markdown]
# ## Applying the model to the 2021 data

# %%
y_pred_21 = pipe_tree.fit(X_train_19, y_train_19).predict(X_21)

# %%
datos_confmat = ConfusionMatrixDisplay.from_estimator(pipe_tree, X_21, y_21)

# %%
f1_score(y_pred_21, y_21, average="macro")
# Out:
# 0.8938263855835229

# %%
matthews_corrcoef(y_pred_21, y_21)
# Out:
# 0.7877091503118203

# %% [markdown]
# ## Modelling with Working Characteristics

# %%
# Lines for the Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV

# Line to split the code
from sklearn.model_selection import train_test_split

# Lines for Standardscaler
from sklearn.preprocessing import StandardScaler

# Line for Decision Tree 
from sklearn.tree import DecisionTreeClassifier

# Line for F1 Score
from sklearn.metrics import f1_score

# Line for Matthews Correlation Coefficient
from sklearn.metrics import matthews_corrcoef

# #Line for confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Setting up the 2019 dataet based on the Working characteristics
X_19_wc = X_19[['P6870', # ¿cuántas personas en total tiene la empresa, negocio, industria, oficina, firma o finca o sitio donde ...Trabaja?
              'P6880', # ¿Dónde realiza principalmente su trabajo:
              'P1881', # ¿Qué medio de transporte utiliza principalmente para desplazarse a su sitio de trabajo?
              'P6240' # ¿en qué actividad ocupó ... la mayor parte del tiempo la semana pasada?
              ]]

# Setting up the 2021 dataet based on the Working characteristics
X_21_wc = X_21[['P6870','P6880','P1881','P6240']]

# We use onehotencoder to encode our categorical varibales into binary columns
ohe = OneHotEncoder(handle_unknown='ignore')

# Create a pipeline
pipe_tree = Pipeline([
    ('preproc', ohe),
    ('model', DecisionTreeClassifier())
    ])

# Splitting our 2019 dataset
X_train, X_test, y_train, y_test = train_test_split(X_19_wc,y_19,test_size = 0.30, random_state=573)

# fitting our model and predicting 2021 values for our 2021 X values
y_pred_tree = pipe_tree.fit(X_train, y_train).predict(X_21_wc)

# %%
#f1 score
f1_score(y_pred_tree, y_21, average="macro")
# Out:
# 0.8994408650967107

# %%
#mcc score
matthews_corrcoef(y_pred_tree, y_21)
# Out:
# 0.7992436042576004
